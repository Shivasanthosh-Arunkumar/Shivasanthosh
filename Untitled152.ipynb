# %% [markdown]
# **Import Libraries**

# %%
import pandas as pd 
import numpy as np
from sklearn import metrics

# %% [markdown]
# **Import Datasets**

# %%
dataset=pd.read_csv('Bank_Personal_Loan_Modelling-1.csv')

# %%
dataset.head()
# Out:
#    ID  Age  Experience  ...  CD Account  Online  CreditCard
# 0   1   25           1  ...           0       0           0
# 1   2   45          19  ...           0       0           0
# 2   3   39          15  ...           0       0           0
# 3   4   35           9  ...           0       0           0
# 4   5   35           8  ...           0       0           1
#
# [5 rows x 14 columns]

# %% [markdown]
# **Drop** **unwanted** **features**

# %%
data=dataset.drop(['ID','ZIP Code','Family'],axis=1)

# %%
data.head()
# Out:
#    Age  Experience  Income  ...  CD Account  Online  CreditCard
# 0   25           1      49  ...           0       0           0
# 1   45          19      34  ...           0       0           0
# 2   39          15      11  ...           0       0           0
# 3   35           9     100  ...           0       0           0
# 4   35           8      45  ...           0       0           1
#
# [5 rows x 11 columns]

# %% [markdown]
# **Create Independent Variable and Target** **Variable**

# %%
data1=data[['Age','Experience','Income','CCAvg','Education','Mortgage','Securities Account','CD Account','Online','CreditCard','Personal Loan']]

# %%
data1.head()
# Out:
#    Age  Experience  Income  ...  Online  CreditCard  Personal Loan
# 0   25           1      49  ...       0           0              0
# 1   45          19      34  ...       0           0              0
# 2   39          15      11  ...       0           0              0
# 3   35           9     100  ...       0           0              0
# 4   35           8      45  ...       0           1              0
#
# [5 rows x 11 columns]

# %% [markdown]
# **Get the Data Information**

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 5000 non-null   int64
#  1   Experience          5000 non-null   int64
#  2   Income              5000 non-null   int64
#  3   CCAvg               5000 non-null   float64
#  4   Education           5000 non-null   int64
#  5   Mortgage            5000 non-null   int64
#  6   Securities Account  5000 non-null   int64
#  7   CD Account          5000 non-null   int64
#  8   Online              5000 non-null   int64
#  9   CreditCard          5000 non-null   int64
#  10  Personal Loan       5000 non-null   int64
# dtypes: float64(1), int64(10)
# memory usage: 429.8 KB

# %% [markdown]
# **Statistics of Data**

# %%
data1.describe(include='all')
# Out:
#                Age   Experience  ...   CreditCard  Personal Loan
# count  5000.000000  5000.000000  ...  5000.000000    5000.000000
# mean     45.338400    20.104600  ...     0.294000       0.096000
# std      11.463166    11.467954  ...     0.455637       0.294621
# min      23.000000    -3.000000  ...     0.000000       0.000000
# 25%      35.000000    10.000000  ...     0.000000       0.000000
# 50%      45.000000    20.000000  ...     0.000000       0.000000
# 75%      55.000000    30.000000  ...     1.000000       0.000000
# max      67.000000    43.000000  ...     1.000000       1.000000
#
# [8 rows x 11 columns]

# %% [markdown]
# **Mean**

# %%
data1.mean()
# Out:
# Age                   45.338400
# Experience            20.104600
# Income                73.774200
# CCAvg                  1.937938
# Education              1.881000
# Mortgage              56.498800
# Securities Account     0.104400
# CD Account             0.060400
# Online                 0.596800
# CreditCard             0.294000
# Personal Loan          0.096000
# dtype: float64

# %% [markdown]
# **Standard** **deviation**

# %%
data1.std()
# Out:
# Age                    11.463166
# Experience             11.467954
# Income                 46.033729
# CCAvg                   1.747659
# Education               0.839869
# Mortgage              101.713802
# Securities Account      0.305809
# CD Account              0.238250
# Online                  0.490589
# CreditCard              0.455637
# Personal Loan           0.294621
# dtype: float64

# %% [markdown]
# **Correlation**

# %%
corr=data1.corr()
corr
# Out:
#                          Age  Experience  ...  CreditCard  Personal Loan
# Age                 1.000000    0.994215  ...    0.007681      -0.007726
# Experience          0.994215    1.000000  ...    0.008967      -0.007413
# Income             -0.055269   -0.046574  ...   -0.002385       0.502462
# CCAvg              -0.052012   -0.050077  ...   -0.006689       0.366889
# Education           0.041334    0.013152  ...   -0.011014       0.136722
# Mortgage           -0.012539   -0.010582  ...   -0.007231       0.142095
# Securities Account -0.000436   -0.001232  ...   -0.015028       0.021954
# CD Account          0.008043    0.010353  ...    0.278644       0.316355
# Online              0.013702    0.013898  ...    0.004210       0.006278
# CreditCard          0.007681    0.008967  ...    1.000000       0.002802
# Personal Loan      -0.007726   -0.007413  ...    0.002802       1.000000
#
# [11 rows x 11 columns]

# %% [markdown]
# **Covariance**

# %%
data1.cov()
# Out:
#                            Age  Experience  ...  CreditCard  Personal Loan
# Age                 131.404166  130.698543  ...    0.040118      -0.026092
# Experience          130.698543  131.513962  ...    0.046857      -0.025047
# Income              -29.164822  -24.587099  ...   -0.050025       6.814640
# CCAvg                -1.041997   -1.003637  ...   -0.005327       0.188910
# Education             0.397949    0.126673  ...   -0.004215       0.033831
# Mortgage            -14.619518  -12.342843  ...   -0.335114       4.258167
# Securities Account   -0.001529   -0.004321  ...   -0.002094       0.001978
# CD Account            0.021965    0.028288  ...    0.030248       0.022206
# Online                0.077058    0.078190  ...    0.000941       0.000907
# CreditCard            0.040118    0.046857  ...    0.207606       0.000376
# Personal Loan        -0.026092   -0.025047  ...    0.000376       0.086801
#
# [11 rows x 11 columns]

# %% [markdown]
# **Variance**

# %%
data1.var()
# Out:
# Age                     131.404166
# Experience              131.513962
# Income                 2119.104235
# CCAvg                     3.054312
# Education                 0.705380
# Mortgage              10345.697538
# Securities Account        0.093519
# CD Account                0.056763
# Online                    0.240678
# CreditCard                0.207606
# Personal Loan             0.086801
# dtype: float64

# %% [markdown]
# **BoxPlot**

# %%
import seaborn as sns
sns.boxplot(x='Education',y='Age',data=dataset)
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
sns.boxplot(x='Personal Loan',y='Age',data=dataset)

# %%
sns.boxplot(x='Online',y='Experience',data=dataset)

# %% [markdown]
# **Histogram**

# %%
import matplotlib.pyplot as plt
dataset.hist(figsize=(20,30))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f0fb028d908>,
# ...
#       dtype=object)

# %% [markdown]
# Distributive Plot

# %%
sns.distplot(data1['Age'])

# %%
sns.distplot(data1['Education'])

# %%
sns.distplot(data1['Personal Loan'])

# %% [markdown]
# **Crosstab**

# %%
pd.crosstab(dataset['Education'],dataset['Personal Loan'])
# Out:
# Personal Loan     0    1
# Education
# 1              2003   93
# 2              1221  182
# 3              1296  205

# %%
pd.crosstab(dataset['CreditCard'],dataset['Personal Loan'])
# Out:
# Personal Loan     0    1
# CreditCard
# 0              3193  337
# 1              1327  143

# %%
pd.crosstab(dataset['Family'],dataset['Securities Account'])
# Out:
# Securities Account     0    1
# Family
# 1                   1330  142
# 2                   1161  135
# 3                    904  106
# 4                   1083  139

# %% [markdown]
# **CountPlot**

# %%
sns.countplot(x='Personal Loan',hue='Family',data=dataset)

# %%
sns.countplot(x='Age',hue='Education',data=dataset,saturation=1,dodge=False)

# %%
sns.countplot(x='Securities Account',hue='CD Account',data=dataset,dodge=False)

# %% [markdown]
# **PairPLot**

# %%
sns.pairplot(data1,hue='Personal Loan')

# %% [markdown]
# **Pivot** **Table**

# %%
pd.pivot_table(dataset,index=['Family','Education'],columns=['Age'],aggfunc=len)
# Out:
#                  CCAvg                         ... ZIP Code
# Age                 23   24    25    26    27  ...       63    64    65   66   67
# Family Education                               ...
# 1      1           1.0  3.0   5.0   6.0   9.0  ...     12.0   9.0  10.0  2.0  1.0
#        2           NaN  NaN   NaN   5.0   7.0  ...     10.0   4.0   5.0  2.0  NaN
#        3           NaN  1.0   1.0   2.0   6.0  ...      8.0   9.0  10.0  4.0  1.0
# 2      1           1.0  4.0   4.0  10.0  13.0  ...     20.0   9.0  10.0  1.0  3.0
#        2           3.0  4.0   4.0   4.0   2.0  ...      2.0   2.0   1.0  NaN  NaN
#        3           NaN  3.0   7.0  10.0   3.0  ...     16.0  14.0   2.0  3.0  NaN
# 3      1           NaN  2.0   2.0   2.0   8.0  ...      2.0   6.0   7.0  6.0  1.0
#        2           1.0  3.0   5.0   7.0   8.0  ...      6.0   5.0  10.0  NaN  NaN
#        3           NaN  1.0   4.0   6.0   3.0  ...      6.0   4.0   9.0  2.0  1.0
# ...

# %%
pd.pivot_table(dataset,'Income',index=['Family','Age'],columns=['CreditCard'],aggfunc=len)
# Out:
# CreditCard     0     1
# Family Age
# 1      23    NaN   1.0
#        24    4.0   NaN
#        25    5.0   1.0
#        26   11.0   2.0
#        27   15.0   7.0
# ...          ...   ...
# 4      63   16.0  10.0
#        64   11.0   5.0
#        65   10.0   6.0
#        66    2.0   2.0
#        67    4.0   1.0
#
# [180 rows x 2 columns]

# %% [markdown]
# **Create Dependent and Independent Variable**

# %%
x=data1.iloc[:,0:9].values
y=data1.iloc[:,10].values

# %%
print(x)
# Out:
# [[25.  1. 49. ...  1.  0.  0.]
#  [45. 19. 34. ...  1.  0.  0.]
#  [39. 15. 11. ...  0.  0.  0.]
#  ...
#  [63. 39. 24. ...  0.  0.  0.]
#  [65. 40. 49. ...  0.  0.  1.]
#  [28.  4. 83. ...  0.  0.  1.]]

# %%
print(y)
# Out:
# [0 0 0 ... 0 0 0]

# %% [markdown]
# **Splitting Data into Train and Test Set**

# %%
from sklearn.model_selection import train_test_split
seed=15
test_size=0.30
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=test_size,random_state=seed)

# %%
print(x_train)
# Out:
# [[50. 24. 80. ...  0.  0.  1.]
#  [28.  4. 45. ...  0.  0.  1.]
#  [60. 34. 35. ...  0.  0.  1.]
#  ...
#  [63. 37. 20. ...  0.  0.  0.]
#  [55. 29. 62. ...  0.  0.  1.]
#  [65. 39. 44. ...  0.  0.  1.]]

# %%
print(x_test)
# Out:
# [[ 42.  16.  32. ...   0.   0.   1.]
#  [ 54.  30.  24. ...   1.   0.   0.]
#  [ 62.  37. 125. ...   0.   0.   1.]
#  ...
#  [ 30.   4.  40. ...   0.   0.   1.]
#  [ 43.  19.  54. ...   0.   0.   1.]
#  [ 61.  36.  40. ...   1.   0.   1.]]

# %%
print(y_train)
# Out:
# [0 0 0 ... 0 0 0]

# %%
print(y_test)
# Out:
# [0 0 1 ... 0 0 0]

# %% [markdown]
# **Create Feature Scaling**

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %% [markdown]
# **Train Data With Random Forest Classifier**

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators=10,criterion='entropy',random_state=10)
classifier.fit(x_train, y_train)
y_predict = classifier.predict(x_test)
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_predict)
print(cm)
from sklearn.model_selection import cross_val_score
accuracies=cross_val_score(estimator=classifier,X=x_train,y=y_train,cv=10)
print('Accuracy: {:.2f}%'.format(accuracies.mean() *100))
print('Standard Deviation: {:.2f}%'.format(accuracies.std() *100))
# Out:
# [[1353    8]
#  [  38  101]]
# Accuracy: 96.83%
# Standard Deviation: 1.09%

# %%
print(classifier.predict([[25,1,49,1.6,1,0,1,0,0]])>0.5)
# Out:
# [ True]

# %% [markdown]
# **Train Data With Decision Tree Classifier**

# %%
from sklearn.tree import DecisionTreeClassifier
classifier=DecisionTreeClassifier(criterion='entropy',random_state=10)
classifier.fit(x_train,y_train)
y_predict=classifier.predict(x_test)
from sklearn.metrics import confusion_matrix 
cm=confusion_matrix(y_predict,y_test)
print(cm)
from sklearn.model_selection import cross_val_score
accuracies=cross_val_score(estimator=classifier,X=x_train,y=y_train,cv=10)
print("Accuracy:{:.2f}%".format(accuracies.mean()*100))
print("Standard Deviation:{:.2f}%".format(accuracies.std()*100))
# Out:
# [[1324   33]
#  [  37  106]]
# Accuracy:96.14%
# Standard Deviation:0.92%

# %%
print(classifier.predict([[25,1,49,1.6,1,0,1,0,0]])>0.5)
# Out:
# [ True]

# %% [markdown]
# **Train Data With SVC**

# %%
from sklearn.svm import SVC
classifier=SVC(kernel='rbf',random_state=10)
classifier.fit(x_train,y_train)
y_predict=classifier.predict(x_test)
from sklearn.metrics import confusion_matrix 
cm=confusion_matrix(y_predict,y_test)
print(cm)
from sklearn.model_selection import cross_val_score
accuracies=cross_val_score(estimator=classifier,X=x_train,y=y_train,cv=10)
print("Accuracy:{:.2f}%".format(accuracies.mean()*100))
print("Standard Deviation:{:.2f}%".format(accuracies.std()*100))
# Out:
# [[1357   43]
#  [   4   96]]
# Accuracy:96.37%
# Standard Deviation:0.78%

# %% [markdown]
# **Train Data With Linear SVC**

# %%
from sklearn.svm import SVC
classifier=SVC(kernel='linear',random_state=10)
classifier.fit(x_train,y_train)
y_predict=classifier.predict(x_test)
from sklearn.metrics import confusion_matrix 
cm=confusion_matrix(y_predict,y_test)
print(cm)
from sklearn.model_selection import cross_val_score
accuracies=cross_val_score(estimator=classifier,X=x_train,y=y_train,cv=10)
print("Accuracy:{:.2f}%".format(accuracies.mean()*100))
print("Standard Deviation:{:.2f}%".format(accuracies.std()*100))
# Out:
# [[1352   63]
#  [   9   76]]
# Accuracy:94.89%
# Standard Deviation:1.04%

# %%
print(classifier.predict([[45,19,34,1.5,1,0,1,0,0]])>0.5)
# Out:
# [ True]

# %% [markdown]
# **Train Data With Logistic Regression**

# %%
from sklearn.linear_model import LogisticRegression
classifier=LogisticRegression(random_state=10)
classifier.fit(x_train,y_train)
y_predict=classifier.predict(x_test)
from sklearn.metrics import confusion_matrix 
cm=confusion_matrix(y_predict,y_test)
print(cm)
from sklearn.model_selection import cross_val_score
accuracies=cross_val_score(estimator=classifier,X=x_train,y=y_train,cv=10)
print("Accuracy:{:.2f}%".format(accuracies.mean()*100))
print("Standard Deviation:{:.2f}%".format(accuracies.std()*100))
# Out:
# [[1345   61]
#  [  16   78]]
# Accuracy:94.49%
# Standard Deviation:1.07%

# %% [markdown]
# **Train Data With KNN**

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier=KNeighborsClassifier(n_neighbors=10,metric='minkowski',p=2)
classifier.fit(x_train,y_train)
y_predict=classifier.predict(x_test)
from sklearn.metrics import confusion_matrix 
cm=confusion_matrix(y_predict,y_test)
print(cm)
from sklearn.model_selection import cross_val_score
accuracies=cross_val_score(estimator=classifier,X=x_train,y=y_train,cv=10)
print("Accuracy:{:.2f}%".format(accuracies.mean()*100))
print("Standard Deviation:{:.2f}%".format(accuracies.std()*100))
# Out:
# [[1357   65]
#  [   4   74]]
# Accuracy:94.86%
# Standard Deviation:0.86%

# %% [markdown]
# **Train Data With Naive Bayes**

# %%
from sklearn.naive_bayes import GaussianNB
classifier=GaussianNB()
classifier.fit(x_train,y_train)
y_predict=classifier.predict(x_test)
from sklearn.metrics import confusion_matrix 
cm=confusion_matrix(y_predict,y_test)
print(cm)
from sklearn.model_selection import cross_val_score
accuracies=cross_val_score(estimator=classifier,X=x_train,y=y_train,cv=10)
print("Accuracy:{:.2f}%".format(accuracies.mean()*100))
print("Standard Deviation:{:.2f}%".format(accuracies.std()*100))
# Out:
# [[1244   55]
#  [ 117   84]]
# Accuracy:88.09%
# Standard Deviation:1.00%

# %% [markdown]
# **Conclusion**

# %% [markdown]
# Random Forest Classifier :96.83%,
# Decision Tree Classifier :96.14% ,
# Naive Bayes :88.09%,
# KNN :94.86% ,
# Logistic Regression :94.49%,
# SVC :96.37% .
# The classification goal is to predict the likelihood of a liability customer buying personal loans.
# A bank wants a new marketing campaign; so that they need information about the correlation between the variables given in the dataset.Here I used 4 classification models to study.**From the accuracy scores , it seems like "Random Forest Classifier" algorithm have the highest accuracy and stability.**
# But we can use SVM also as all the Kernels have good accuracy as well.
